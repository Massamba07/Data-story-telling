# %%
from dash import Dash, dcc, html, dash_table, Input, Output, callback
import plotly.express as px
import dash_bootstrap_components as dbc
from dash_bootstrap_templates import ThemeChangerAIO, template_from_url
import pandas as pd
import pages as pa

# DATA
df = px.data.gapminder()
years = df.year.unique()
continents = df.continent.unique()

# INIT
app = Dash(__name__, external_stylesheets=[dbc.themes.QUARTZ], title="Ynov Data Science Project")
server = app.server

# ===========================================================================================================================================

# HEADER
header = html.H4(
    "Data Storytelling : GBE - GUEYE - KARAYANNIDIS",
    className="text-white p-2 mb-2 text-center", 
    style=pa.HEADER_STYLE
)

# ===========================================================================================================================================


# SIDEBAR
sidebar = html.Div(
    [
        html.H2("Sommaire", className="display-4"),
        html.Hr(),
        html.P(
            "Expliquer les fluctuations des prix de l'alimentaire", className="lead"
        ),
        dbc.Nav(
            [
                dbc.NavLink("Page 1", href="/", active="exact"),
                dbc.NavLink("Page 2", href="/page-2", active="exact"),
                dbc.NavLink("Page 3", href="/page-3", active="exact"),
                dbc.NavLink("Page 4", href="/page-4", active="exact"),
                dbc.NavLink("Page 5", href="/page-5", active="exact"),
                dbc.NavLink("Page 6", href="/page-6", active="exact"),
                dbc.NavLink("Page 7", href="/page-7", active="exact"),
            ],
            vertical=True,
            pills=True,
            style={"justify-content": "space-evenly"}
        ),
        html.Hr(),
        html.Img(
            src="https://imgs.search.brave.com/b_218gQQ1bSwOLEcJh_-Uaub-PKt8qVzOZQzN0nYKrY/rs:fit:381:150:1/g:ce/aHR0cHM6Ly93d3cu/eW5vdi1haXguZnIv/d3AtY29udGVudC91/cGxvYWRzLzIwMTcv/MDUvTG9nby1Zbm92/LUFpeC0xNTBweC5w/bmc", 
            width="70%", 
            style={"margin":"auto"}),
        html.Hr(),
        ThemeChangerAIO(aio_id="theme", 
                        radio_props={"value":dbc.themes.QUARTZ}, 
                        button_props={"children":"Changer le thème"}, 
                        offcanvas_props={"title":"Choisir un thème"})
    ],
    style=pa.SIDEBAR_STYLE
)

# LE LAYOUT
app.layout = dbc.Container(
    [
        dcc.Location(id="url"),
        header,
        dbc.Col(
            sidebar,
            style={"width":"13%"}
        ),
        html.Div(
            id='page-content'
        ),
    ],
    fluid=True,
    className="dbc", style={"height":"50%"}
)

# ===========================================================================================================================================

# PAGES
@callback(Output('page-content', 'children'),
             [Input('url', 'pathname')])
def display_page(pathname):
    if pathname == '/page-2':
        return pa.layout2
    elif pathname == "/":
        return pa.layout1
    return html.Div(
    [
        html.H1("404: Not found", className="text-danger"),
        html.Hr(),
        html.P(
            f"Le chemin {pathname} n'existe pas...", 
               style={
                    "color":"red",
                    "text-align": "center"
               }
              ),
        html.Hr(),
        html.Img(
            src="https://media.tenor.com/tL4TpMpm7DsAAAAM/sajna-sad.gif",
                style=pa.IMG_404
        )
    ],
        className="p-3 bg-light rounded-3",
        style=pa.CONTENT_STYLE
    )

# %%
app.run_server(debug=False, port=8080)
# Out:
# Dash is running on http://127.0.0.1:8080/
#
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:8080
# Press CTRL+C to quit
# 127.0.0.1 - - [02/Jan/2023 16:12:57] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Jan/2023 16:12:57] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Jan/2023 16:12:57] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Jan/2023 16:12:57] "GET /_favicon.ico?v=2.6.1 HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Jan/2023 16:12:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Jan/2023 16:12:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Jan/2023 16:12:58] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 304 -
# 127.0.0.1 - - [02/Jan/2023 16:12:58] "GET /_dash-component-suites/dash/dash_table/async-highlight.js HTTP/1.1" 304 -
# 127.0.0.1 - - [02/Jan/2023 16:12:58] "GET /_dash-component-suites/dash/dash_table/async-table.js HTTP/1.1" 304 -
# 127.0.0.1 - - [02/Jan/2023 16:12:58] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 304 -
# 127.0.0.1 - - [02/Jan/2023 16:12:58] "GET /_dash-component-suites/dash/dcc/async-slider.js HTTP/1.1" 304 -
# 127.0.0.1 - - [02/Jan/2023 16:12:58] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 304 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/nansk/.local/lib/python3.10/site-packages/flask/app.py", line 2525, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/nansk/.local/lib/python3.10/site-packages/flask/app.py", line 1822, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/nansk/.local/lib/python3.10/site-packages/flask/app.py", line 1820, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/nansk/.local/lib/python3.10/site-packages/flask/app.py", line 1796, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "/home/nansk/.local/lib/python3.10/site-packages/dash/dash.py", line 1259, in dispatch
#     ctx.run(
#   File "/home/nansk/.local/lib/python3.10/site-packages/dash/_callback.py", line 439, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/home/nansk/DS_ST_PROJECT/src/pages/page1.py", line 153, in update_line_chart
#     fig = gen.creating_grph("line", dataframe=dff, x_axis="year", y_axis=indicator)
#   File "/home/nansk/DS_ST_PROJECT/src/pages/gen.py", line 12, in creating_grph
#     line_group=line_group, template=template_from_url(theme))
# NameError: name 'line_group' is not defined
# 127.0.0.1 - - [02/Jan/2023 16:12:58] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [02/Jan/2023 16:13:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Jan/2023 16:13:01] "GET /_favicon.ico?v=2.6.1 HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Jan/2023 16:13:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Jan/2023 16:13:05] "GET /_favicon.ico?v=2.6.1 HTTP/1.1" 200 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/nansk/.local/lib/python3.10/site-packages/flask/app.py", line 2525, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/nansk/.local/lib/python3.10/site-packages/flask/app.py", line 1822, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/nansk/.local/lib/python3.10/site-packages/flask/app.py", line 1820, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/nansk/.local/lib/python3.10/site-packages/flask/app.py", line 1796, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "/home/nansk/.local/lib/python3.10/site-packages/dash/dash.py", line 1259, in dispatch
#     ctx.run(
#   File "/home/nansk/.local/lib/python3.10/site-packages/dash/_callback.py", line 439, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/home/nansk/DS_ST_PROJECT/src/pages/page1.py", line 153, in update_line_chart
#     fig = gen.creating_grph("line", dataframe=dff, x_axis="year", y_axis=indicator)
#   File "/home/nansk/DS_ST_PROJECT/src/pages/gen.py", line 12, in creating_grph
#     line_group=line_group, template=template_from_url(theme))
# NameError: name 'line_group' is not defined
# 127.0.0.1 - - [02/Jan/2023 16:13:05] "POST /_dash-update-component HTTP/1.1" 500 -
